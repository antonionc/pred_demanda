# %% [markdown]
# # Fase 2.3 — Modelo TTM (Tiny Time Mixers — IBM Granite)
#
# **Thesis:** Comparativa de algoritmos para la predicción de la demanda eléctrica
# **Author:** Antonio Navarro
#
# This notebook evaluates the IBM Granite Tiny Time Mixers foundation model
# (`ibm/granite-timeseries-ttm-r2`) in two modes:
#
# 1. **Zero-shot** — load the pre-trained model, run inference with no fine-tuning
# 2. **Few-shot** — fine-tune on 5% of training data, then evaluate on the test set
#
# The model context length is **512 hours** → forecast horizon **24 hours**.
#
# ### Installation (run once in your venv)
# ```bash
# pip install "granite-tsfm[notebooks]>=0.2" transformers>=4.40 datasets>=2.14 accelerate>=0.27
# ```

# %%
# Install dependencies not pre-installed in Colab
import importlib, subprocess, sys

def _pip(pkg, import_name=None):
    if importlib.util.find_spec(import_name or pkg) is None:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", pkg])

_pip("granite-tsfm[notebooks]", "tsfm_public")
_pip("transformers")
_pip("accelerate")
print("Dependencies ready.")
# Out:
# Dependencies ready.

# %%
import sys, os, time, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import torch

# ── Colab: clone or update the repo, then cd into it ──────────────────────────
REPO_NAME = "pred_demanda"
REPO_URL  = "https://github.com/antonionc/pred_demanda.git"

if os.path.exists("data_utils.py"):
    # !git pull
elif os.path.isdir(REPO_NAME):
    # %cd {REPO_NAME}
    # !git pull
elif os.path.exists(f"/content/{REPO_NAME}"):
    # %cd /content/{REPO_NAME}
    # !git pull
elif os.path.exists("/content"):
    # !git clone {REPO_URL}
    # %cd {REPO_NAME}
# ──────────────────────────────────────────────────────────────────────────────

sys.path.insert(0, os.path.abspath('.'))
import data_utils as du

# Mount Google Drive in Colab and create persistent links for data/, cache/, saved_models/
du.setup_colab_drive()

# Set up Hugging Face token (reads .env / environment / Colab UI safely)
du.setup_hf_token()

np.random.seed(42)
plt.rcParams.update({'figure.dpi': 100, 'axes.grid': True, 'grid.alpha': 0.3})

DEVICE = 'cuda' if torch.cuda.is_available() else ('mps' if torch.backends.mps.is_available() else 'cpu')
print(f'Device: {DEVICE}')
# Out:
# Cloning into 'pred_demanda'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 129 (delta 75), reused 76 (delta 32), pack-reused 0 (from 0)
# Receiving objects: 100% (129/129), 3.42 MiB | 17.80 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# /content/pred_demanda
# [Colab] Requesting scoped access to Google Drive ('drive.file')...
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
#   [DriveSync] Downloading data/fig_boxcox.png...
#   [DriveSync] Downloading data/predictions_ttm_fewshot.csv...
#   [DriveSync] Downloading data/features_test.csv...
#   [DriveSync] Downloading data/features_train.csv...
#   [DriveSync] Downloading data/fig_seasonality.png...
#   [DriveSync] Downloading data/metrics_ttm_fewshot.json...
#   [DriveSync] Downloading data/fig_sarimax_residuals.png...
#   [DriveSync] Downloading data/fig_ttm_fewshot_week.png...
#   [DriveSync] Downloading data/predictions_ttm_zeroshot.csv...
#   [DriveSync] Downloading data/fig_data_split.png...
#   [DriveSync] Downloading data/fig_sarimax_test.png...
#   [DriveSync] Downloading data/hourly_features_full.csv...
#   [DriveSync] Downloading data/metrics_lstm.json...
#   [DriveSync] Downloading data/fig_lstm_test.png...
#   [DriveSync] Downloading data/fig_lstm_week.png...
#   [DriveSync] Downloading data/fig_raw_demand.png...
#   [DriveSync] Downloading data/predictions_sarimax.csv...
#   [DriveSync] Downloading data/metrics_sarimax.json...
#   [DriveSync] Downloading data/fig_lstm_residuals.png...
#   [DriveSync] Downloading data/fig_ttm_finetune.png...
#   [DriveSync] Downloading data/fig_lstm_training.png...
#   [DriveSync] Downloading data/fig_pearson_correlation.png...
#   [DriveSync] Downloading data/predictions_lstm.csv...
#   [DriveSync] Downloading data/features_val.csv...
#   [DriveSync] Downloading data/fig_ttm_comparison_week.png...
#   [DriveSync] Downloading data/fig_ttm_zeroshot_week.png...
#   [DriveSync] Downloading data/metrics_ttm_zeroshot.json...
#   [DriveSync] Downloading data/fig_sarimax_week.png...
#   [DriveSync] Downloading data/fig_stl_decomposition.png...
#   [DriveSync] Downloading data/fig_acf_pacf.png...
#   [DriveSync] Downloading cache/esios_chunk_77722c1924bf152a186b57ff9e13349d.pkl...
#   [DriveSync] Downloading cache/esios_chunk_a9e86e8a2796358418583e0bcf45d62b.pkl...
#   [DriveSync] Downloading cache/esios_chunk_2f49521107f29cd3efcc3a98da7eb27f.pkl...
#   [DriveSync] Downloading cache/esios_chunk_278fa8a241c8fdd5479daa569a1421e0.pkl...
#   [DriveSync] Downloading cache/esios_chunk_ed9eee70691b3750f51bbe1e9837c646.pkl...
#   [DriveSync] Downloading cache/esios_chunk_0ba17a15a3c8a15cd531c19f28184c79.pkl...
#   [DriveSync] Downloading cache/esios_chunk_a7d832fd9b5e6add152e5e7456f3f298.pkl...
#   [DriveSync] Downloading cache/esios_chunk_ab6f9fb9b5391eda8bced7e43617aae2.pkl...
#   [DriveSync] Downloading cache/esios_chunk_effb268722b7fbcc0743443415c052cc.pkl...
#   [DriveSync] Downloading cache/esios_chunk_b9eb979afae1a3ff85cd03d8bc86c9ec.pkl...
#   [DriveSync] Downloading cache/esios_chunk_19c8d48bd32903ea72f6d344ce1a0bce.pkl...
#   [DriveSync] Downloading cache/esios_chunk_ec646bf1f3169df5bcd05867e20fd737.pkl...
#   [DriveSync] Downloading cache/esios_chunk_e397bee21e61eb5df0ad3e65228b3693.pkl...
#   [DriveSync] Downloading cache/esios_chunk_28cb2bc6a803bd0c574cf0d8c05e13a6.pkl...
#   [DriveSync] Downloading cache/esios_chunk_ec5da5d02da0d51983e75f6576ee5c35.pkl...
#   [DriveSync] Downloading cache/esios_chunk_c4769404bfd7adf6bd55d4dc2c0cda04.pkl...
#   [DriveSync] Downloading cache/esios_chunk_2b545e41a47ba530514eac6e4a787fde.pkl...
#   [DriveSync] Downloading cache/esios_chunk_f5b6baa14b1e4bde23757d8ac4991681.pkl...
#   [DriveSync] Downloading cache/esios_chunk_59f29187ddcbb77bf612dfcb355435e5.pkl...
#   [DriveSync] Downloading cache/esios_chunk_096097e19fc09026c1d8f0d50a937213.pkl...
#   [DriveSync] Downloading cache/esios_chunk_16199e237279463f71501809aafd0102.pkl...
#   [DriveSync] Downloading cache/esios_chunk_648c54b5e1fb9d6aebbbc94ad67ffa78.pkl...
#   [DriveSync] Downloading cache/esios_chunk_2ed56b724e28c8bece31bc57503b48e8.pkl...
#   [DriveSync] Downloading cache/esios_chunk_059c27ff0db1037572cf64253fbc7e95.pkl...
#   [DriveSync] Downloading cache/esios_77a3abc1fb28157a9ad20ac4653588dc.pkl...
#   [DriveSync] Downloading cache/esios_chunk_98b0f211d838bbdf4dd71e2c69784881.pkl...
#   [DriveSync] Downloading cache/esios_chunk_1b56ccf9551c6177ab16572b2b25242f.pkl...
#   [DriveSync] Downloading cache/esios_chunk_38629c98a5299dd5877119dcd915d3c5.pkl...
#   [DriveSync] Downloading cache/esios_chunk_91262a792181b2c4f9f9706684e53a79.pkl...
#   [DriveSync] Downloading cache/esios_chunk_067b43ea58fc06ea262ed3ae6e71262d.pkl...
#   [DriveSync] Downloading cache/esios_chunk_3b64ff5000ec74d1d1538277a8273c5d.pkl...
#   [DriveSync] Downloading cache/esios_chunk_04233c88a47818dcf34577ad9896d657.pkl...
#   [DriveSync] Downloading cache/esios_chunk_ba0b69f78cd23a19058c9dd14f218050.pkl...
#   [DriveSync] Downloading cache/esios_chunk_d31874962515cbfcc53c256c6c955713.pkl...
#   [DriveSync] Downloading cache/esios_chunk_edfb372e75a879e69c14711682a28f11.pkl...
#   [DriveSync] Downloading cache/esios_chunk_39816a5e1d04562e01f411db1c28a7f9.pkl...
#   [DriveSync] Downloading cache/esios_chunk_91a38cea51bfe7e40f9e15f2993543ef.pkl...
#   [DriveSync] Downloading cache/esios_chunk_3eec930341dae5d150f85a9b631db468.pkl...
#   [DriveSync] Downloading cache/esios_chunk_4ad3359681b81a3ac70d42c0a1c95c8b.pkl...
#   [DriveSync] Downloading cache/esios_chunk_b8546100ea247c2b31998f366c31e827.pkl...
#   [DriveSync] Downloading cache/esios_chunk_db90a6c5b4372da9b83d14e1ec34d807.pkl...
#   [DriveSync] Downloading cache/esios_chunk_ca3a199a0d77ffebcd001aa417151c0d.pkl...
#   [DriveSync] Downloading cache/esios_00ecea6a9172671e29ec3d65e5617f3f.pkl...
#   [DriveSync] Downloading cache/esios_chunk_48f9263eb87d9a5a34a79e756dcb2145.pkl...
#   [DriveSync] Downloading cache/esios_chunk_de8400b261055c6b2bd3cd78d6539802.pkl...
#   [DriveSync] Downloading cache/esios_chunk_877776a74e30476740bc36153817aac8.pkl...
#   [DriveSync] Downloading cache/esios_chunk_6e5f2c2dbd41f366355aed4c8adbe81b.pkl...
#   [DriveSync] Downloading cache/esios_chunk_a77962559435733f496d5438e86dba3c.pkl...
#   [DriveSync] Downloading cache/esios_chunk_73ea90391c818c722eab9dd92d482958.pkl...
#   [DriveSync] Downloading cache/esios_chunk_a2ad0c6e679aa032602ced1d1369bbd4.pkl...
#   [DriveSync] Downloading cache/esios_chunk_ab254ef7bed6acc37e5841302396ab62.pkl...
#   [DriveSync] Downloading cache/esios_chunk_07173a25320a00a20cf700479646e579.pkl...
#   [DriveSync] Downloading cache/esios_chunk_4b79b19bc2253ff965d9cc46dfe3137d.pkl...
#   [DriveSync] Downloading cache/esios_chunk_e3655cb0e3ed8854e84c2bb81b2543d5.pkl...
#   [DriveSync] Downloading cache/esios_chunk_db9626bae8b1b6de9699bd6c0128e686.pkl...
#   [DriveSync] Downloading cache/esios_chunk_772df9ca8320adab4276c220cc029972.pkl...
#   [DriveSync] Downloading cache/esios_chunk_17d302c92843387ddb79f07effe717a9.pkl...
#   [DriveSync] Downloading cache/esios_chunk_23224be23d237eb4281701cd9aee7829.pkl...
#   [DriveSync] Downloading cache/esios_chunk_8ebad3b87a2566b97b2393d74c544e90.pkl...
#   [DriveSync] Downloading cache/esios_chunk_b85ea7903132d8e1b6805747cb9529d0.pkl...
#   [DriveSync] Downloading cache/esios_chunk_e4e092c57e069e923daa27d80adc33dd.pkl...
#   [DriveSync] Downloading cache/esios_chunk_4da9739fe4aa2556f86a596c0307bf8a.pkl...
#   [DriveSync] Downloading cache/esios_chunk_b10cfb5790b9933c7a287b0982287b92.pkl...
#   [DriveSync] Downloading cache/esios_chunk_69f9d4b7ba466401fb64c0dca86d7feb.pkl...
#   [DriveSync] Downloading cache/openmeteo_8142cc6552233faea0ae6a2154340a30.pkl...
#   [DriveSync] Downloading cache/esios_chunk_8d92c2e94cf97b5d2d1fc3bbdd5b3ddb.pkl...
#   [DriveSync] Downloading cache/esios_chunk_5d2c34fa98a21920666f493ef49dad56.pkl...
#   [DriveSync] Downloading cache/esios_chunk_96d5a75537393184b6d27ea19004b268.pkl...
#   [DriveSync] Downloading cache/esios_chunk_47f5251e7448a990f344c3ccba87097c.pkl...
#   [DriveSync] Downloading cache/esios_chunk_3286042738b4042669013ee7ec9149f7.pkl...
#   [DriveSync] Downloading cache/esios_chunk_ab89c85fcb567c1f27196f33229f805d.pkl...
#   [DriveSync] Downloading cache/esios_chunk_8ad5833b4208904baa740ea21ca7b1be.pkl...
#   [DriveSync] Downloading cache/esios_chunk_2e20f6b00d5664c9ae050b54e164b649.pkl...
#   [DriveSync] Downloading cache/esios_chunk_018a4f151f09d31bd254330f63cda7c4.pkl...
#   [DriveSync] Downloading cache/esios_chunk_aa6bf8aa0be0c756d424d29f1ac0bbf5.pkl...
#   [DriveSync] Downloading cache/esios_chunk_a34cbcfb1aacc0115498645223ad8d86.pkl...
#   [DriveSync] Downloading cache/esios_chunk_51196a5bc5a2fb0fe22647795c1fb569.pkl...
#   [DriveSync] Downloading cache/esios_chunk_54f911966bb33d733dc14f2a09e5f881.pkl...
#   [DriveSync] Downloading cache/esios_chunk_1e0031d40b1c66002db3a298a0fd09b6.pkl...
#   [DriveSync] Downloading cache/esios_chunk_37b133d9716e3876cee22473aca69e9e.pkl...
#   [DriveSync] Downloading cache/esios_chunk_9844632642bdce5705f0307c1efed2d0.pkl...
#   [DriveSync] Downloading cache/esios_chunk_6466513cc67f7bf838c219626c421c67.pkl...
#   [DriveSync] Downloading cache/esios_chunk_97e7857fcb710058642282549e2b625d.pkl...
#   [DriveSync] Downloading cache/esios_chunk_257693848ec50cc9d1c36b9c084e02bd.pkl...
#   [DriveSync] Downloading cache/esios_chunk_e9d2b83992db0d8e5c8e9a82e49b1065.pkl...
#   [DriveSync] Downloading cache/esios_chunk_23eaea2912ff4c00c128c84e32fd29cf.pkl...
#   [DriveSync] Downloading cache/esios_chunk_763edfe57aebef24a2bb28a246bc340c.pkl...
#   [DriveSync] Downloading cache/esios_chunk_17994abd81f14cdd92ea187c68f691f9.pkl...
#   [DriveSync] Downloading cache/esios_chunk_8b2b684148b02002b5867948213024e7.pkl...
#   [DriveSync] Downloading cache/esios_chunk_a2ecb9461c2c71aa659a51d4a99c655e.pkl...
#   [DriveSync] Downloading cache/esios_chunk_6153281b49a9e083fc50bfa4e0815ad9.pkl...
#   [DriveSync] Downloading cache/esios_chunk_ca0a546d4281cf60427efdbca11c4639.pkl...
#   [DriveSync] Downloading cache/esios_chunk_c26d7938cfc50f0d9106260a61c8ccb9.pkl...
#   [DriveSync] Downloading cache/esios_chunk_d3d2e60f51fcbc5fba985541581db99d.pkl...
#   [DriveSync] Downloading cache/esios_chunk_519aa3f7d5dd978345f9e2afa1cfd787.pkl...
#   [DriveSync] Downloading cache/esios_chunk_8f0c90d24f2649bc64678e7729690792.pkl...
#   [DriveSync] Downloading cache/openmeteo_5a2942590f7449a0b98e9ab046c3ef7f.pkl...
#   [DriveSync] Downloading cache/esios_chunk_ee59568009c9a40e75b0014a1fc92104.pkl...
#   [DriveSync] Downloading cache/esios_chunk_ad082ad2ca00cba8a6d4a4869db29f4e.pkl...
#   [DriveSync] Downloading cache/esios_chunk_ce0872f58f12cb7b4c73d5f36f4a5580.pkl...
#   [DriveSync] Downloading saved_models/lstm_best.keras...
# [DriveSync] Sync from Google Drive complete.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HuggingFace] Login successful.
# Device: cuda

# %%
# granite-tsfm imports
try:
    from tsfm_public.models.tinytimemixer import (
        TinyTimeMixerForPrediction,
        TinyTimeMixerConfig,
    )
    from tsfm_public import TinyTimeMixerForPrediction  # noqa (alias)
    from tsfm_public.toolkit.dataset import ForecastDFDataset
    from tsfm_public.toolkit.time_series_forecasting_pipeline import TimeSeriesForecastingPipeline
    from transformers import EarlyStoppingCallback, Trainer, TrainingArguments
    print('granite-tsfm imported successfully')
except ImportError as e:
    print(f'Import error: {e}')
    print('Install with: pip install "granite-tsfm[notebooks]"')
    raise
# Out:
# granite-tsfm imported successfully

# %% [markdown]
# ## 1 · Load and prepare data

# %%
df_train = pd.read_csv('data/features_train.csv', parse_dates=['datetime'])
df_val   = pd.read_csv('data/features_val.csv',   parse_dates=['datetime'])
df_test  = pd.read_csv('data/features_test.csv',  parse_dates=['datetime'])

# TTM model parameters
CONTEXT_LEN = 512    # 512-hour historical context window (~21 days)
HORIZON     = 24     # 24-hour forecast horizon
TARGET_COL  = 'demand_mw'

# TTMs work best with univariate signals, so we remove the noise (exogenous variables)

print(f'Target variable : {TARGET_COL}')
print(f'Train : {len(df_train):,}  Val : {len(df_val):,}  Test : {len(df_test):,}')
# Out:
# Target variable : demand_mw
# Train : 29,259  Val : 9,753  Test : 9,754

# %%
from sklearn.preprocessing import StandardScaler

# Standardize target channel
scaler = StandardScaler()
scaler.fit(df_train[[TARGET_COL]])

def scale_df(df):
    out = df.copy()
    out[[TARGET_COL]] = scaler.transform(df[[TARGET_COL]])
    return out

df_train_sc = scale_df(df_train)
df_val_sc   = scale_df(df_val)
df_test_sc  = scale_df(df_test)

# Concatenated history for zero-shot inference (train + val as context)
df_history = pd.concat([df_train_sc, df_val_sc], ignore_index=True)
print(f'History length for zero-shot: {len(df_history):,} rows')
# Out:
# History length for zero-shot: 39,012 rows

# %%
TTM_MODEL_ID = 'ibm-granite/granite-timeseries-ttm-r2'

print(f'Loading {TTM_MODEL_ID}…')
zs_model = TinyTimeMixerForPrediction.from_pretrained(
    TTM_MODEL_ID,
    prediction_filter_length = HORIZON,
)
zs_model = zs_model.to(DEVICE)
zs_model.eval()

config = zs_model.config
print(f'Context length : {config.context_length}')
print(f'Forecast length: {config.prediction_length}')
print(f'Parameters     : {sum(p.numel() for p in zs_model.parameters()):,}')
# Out:
# Loading ibm-granite/granite-timeseries-ttm-r2…
# config.json:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.24MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/134 [00:00<?, ?it/s]
# Context length : 512
# Forecast length: 96
# Parameters     : 805,280

# %% [markdown]
# ## 3 · Build ForecastDFDatasets

# %%
def make_dataset(df, context_len=CONTEXT_LEN, horizon=HORIZON, stride=1):
    """Wrap a DataFrame in ForecastDFDataset expected by granite-tsfm."""
    return ForecastDFDataset(
        df,
        id_columns           = [],
        timestamp_column     = 'datetime',
        target_columns       = [TARGET_COL],
        conditional_columns  = [],
        context_length       = context_len,
        prediction_length    = horizon,
        stride               = stride,
    )

# Zero-shot test dataset: use last CONTEXT_LEN rows of history as prefix,
# then test data — ensures every prediction window falls within the test period.
df_for_zs_test = pd.concat([
    df_history.tail(CONTEXT_LEN).reset_index(drop=True),
    df_test_sc,
], ignore_index=True)

# stride=HORIZON gives non-overlapping daily predictions
test_dataset_zs = make_dataset(df_for_zs_test, stride=HORIZON)
print(f'Zero-shot test dataset: {len(test_dataset_zs)} windows')

# Few-shot fine-tuning dataset: sample 5% of windows uniformly across all 3.5 years (stride=24)
fs_train_ds = make_dataset(df_train_sc, stride=24)
fs_val_ds   = make_dataset(df_val_sc,   stride=HORIZON)
print(f'Few-shot train dataset  : {len(fs_train_ds)} windows (sampled across full 3.5-year history)')
print(f'Few-shot val dataset    : {len(fs_val_ds)} windows')
# Out:
# Zero-shot test dataset: 406 windows
# Few-shot train dataset  : 1197 windows (sampled across full 3.5-year history)
# Few-shot val dataset    : 385 windows

# %%
from torch.utils.data import DataLoader
from torch.utils.data.dataloader import default_collate

def collate_skip_timestamps(batch):
    """Drop pandas Timestamp fields that PyTorch's default collate cannot handle."""
    filtered = [
        {k: v for k, v in item.items() if not isinstance(v, pd.Timestamp)}
        for item in batch
    ]
    return default_collate(filtered)

t0  = time.time()
loader = DataLoader(test_dataset_zs, batch_size=64, shuffle=False,
                    collate_fn=collate_skip_timestamps)

preds_zs, trues_zs = [], []

with torch.no_grad():
    for batch in loader:
        past_values = batch['past_values'].to(DEVICE)
        outputs     = zs_model(past_values=past_values)
        preds_zs.append(outputs.prediction_outputs.cpu().numpy())
        trues_zs.append(batch['future_values'].numpy())

inference_time_zs = time.time() - t0

preds_zs = np.concatenate(preds_zs, axis=0)   # (n_windows, horizon, 1)
trues_zs = np.concatenate(trues_zs, axis=0)

# Extract target channel (index 0) and inverse-transform
target_mean = scaler.mean_[0]
target_std  = scaler.scale_[0]

y_pred_zs = preds_zs[:, :, 0].ravel() * target_std + target_mean
y_true_zs = trues_zs[:, :, 0].ravel() * target_std + target_mean

print(f'Inference time (zero-shot): {inference_time_zs:.2f}s')
print(f'Forecast points: {len(y_pred_zs):,}')
# Out:
# Inference time (zero-shot): 1.11s
# Forecast points: 9,744

# %%
metrics_zs = du.compute_metrics(y_true_zs, y_pred_zs, label='TTM zero-shot')
metrics_zs['train_s']     = 0.0
metrics_zs['inference_s'] = inference_time_zs
# Out:
# [TTM zero-shot] MAPE=6.109%  RMSE=1828.7 MW  MAE=1336.1 MW

# %% [markdown]
# ## 5 · Few-shot fine-tuning (5% of training data)

# %%
# REMOVE/comment later
# debugging an issue with the TRainingArguments consutructor
import inspect
import transformers

print("Transformers version:", transformers.__version__)
print("TrainingArguments class :", TrainingArguments)
print("Defined in module       :", TrainingArguments.__module__)
try:
    print("Source file             :", inspect.getfile(TrainingArguments))
except Exception:
    pass
print("\nAccepted constructor parameters:")
print(inspect.signature(TrainingArguments.__init__))
# Out:
# Transformers version: 5.16.1
# TrainingArguments class : <class 'transformers.training_args.TrainingArguments'>
# Defined in module       : transformers.training_args
# Source file             : /usr/local/lib/python3.13/dist-packages/transformers/training_args.py
#
# Accepted constructor parameters:
# (self, output_dir: str | None = None, per_device_train_batch_size: int = 8, num_train_epochs: float = 3.0, max_steps: int = -1, learning_rate: float = 5e-05, lr_scheduler_type: transformers.trainer_utils.SchedulerType | str = 'linear', lr_scheduler_kwargs: dict | str | None = None, warmup_steps: float = 0, optim: transformers.training_args.OptimizerNames | str = 'adamw_torch_fused', optim_args: str | None = None, weight_decay: float = 0.0, adam_beta1: float = 0.9, adam_beta2: float = 0.999, adam_epsilon: float = 1e-08, optim_target_modules: None | str | list[str] = None, gradient_accumulation_steps: int = 1, average_tokens_across_devices: bool = True, max_grad_norm: float = 1.0, label_smoothing_factor: float = 0.0, bf16: bool = False, fp16: bool = False, bf16_full_eval: bool = False, fp16_full_eval: bool = False, tf32: bool | None = None, gradient_checkpointing: bool = False, gradient_checkpointing_kwargs: dict[str, typing.Any] | str | None = None, torch_compile: bool = False, torch_compile_backend: str | None = None, torch_compile_mode: str | None = None, use_liger_kernel: bool = False, liger_kernel_config: dict[str, bool] | None = None, use_cache: bool = False, neftune_noise_alpha: float | None = None, torch_empty_cache_steps: int | None = None, auto_find_batch_size: bool = False, logging_strategy: transformers.trainer_utils.IntervalStrategy | str = 'steps', logging_steps: float = 500, logging_first_step: bool = False, log_on_each_node: bool = True, logging_nan_inf_filter: bool = True, include_num_input_tokens_seen: str | bool = 'no', log_level: str = 'passive', log_level_replica: str = 'warning', disable_tqdm: bool | None = None, report_to: None | str | list[str] = 'none', run_name: str | None = None, project: str = 'huggingface', trackio_space_id: str | None = None, trackio_bucket_id: str | None = None, trackio_static_space_id: Union[str, NoneType, Literal[False]] = None, eval_strategy: transformers.trainer_utils.IntervalStrategy | str = 'no', eval_steps: float | None = None, eval_delay: float = 0, per_device_eval_batch_size: int = 8, prediction_loss_only: bool = False, eval_on_start: bool = False, eval_do_concat_batches: bool = True, eval_use_gather_object: bool = False, eval_accumulation_steps: int | None = None, include_for_metrics: list[str] = <factory>, batch_eval_metrics: bool = False, save_only_model: bool = False, save_strategy: transformers.trainer_utils.SaveStrategy | str = 'steps', save_steps: float = 500, save_on_each_node: bool = False, save_total_limit: int | None = None, enable_jit_checkpoint: bool = False, push_to_hub: bool = False, hub_token: str | None = None, hub_private_repo: bool | None = None, hub_model_id: str | None = None, hub_strategy: transformers.trainer_utils.HubStrategy | str = 'every_save', hub_always_push: bool = False, hub_revision: str | None = None, load_best_model_at_end: bool = False, metric_for_best_model: str | None = None, greater_is_better: bool | None = None, ignore_data_skip: bool = False, restore_callback_states_from_checkpoint: bool = False, full_determinism: bool = False, seed: int = 42, data_seed: int | None = None, use_cpu: bool = False, accelerator_config: dict | str | None = None, parallelism_config: accelerate.parallelism_config.ParallelismConfig | None = None, dataloader_drop_last: bool = False, dataloader_num_workers: int = 0, dataloader_pin_memory: bool = True, dataloader_persistent_workers: bool = False, dataloader_prefetch_factor: int | None = None, dataloader_multiprocessing_context: str | None = None, dataloader_in_order: bool = True, remove_unused_columns: bool = True, label_names: list[str] | None = None, train_sampling_strategy: str = 'random', length_column_name: str = 'length', ddp_find_unused_parameters: bool | None = None, ddp_bucket_cap_mb: int | None = None, ddp_broadcast_buffers: bool | None = None, ddp_static_graph: bool | None = None, ddp_backend: str | None = None, ddp_timeout: int = 1800, fsdp: str | None = None, fsdp_config: dict[str, typing.Any] | st ...

# %%
# Load pre-trained model in native Channel-Independent mode (preserves zero-shot curve)
fs_model = TinyTimeMixerForPrediction.from_pretrained(
    TTM_MODEL_ID,
    prediction_filter_length = HORIZON,
)

# Gentle fine-tuning: allow small learning rate adaptation across the model
# (or train prediction head with pre-trained weights intact)
for param in fs_model.backbone.parameters():
    param.requires_grad = True

print(f'Trainable parameters: {sum(p.numel() for p in fs_model.parameters() if p.requires_grad):,}')

training_args = TrainingArguments(
    output_dir                  = 'saved_models/ttm_fewshot',
    num_train_epochs            = 10,
    per_device_train_batch_size = 64,
    per_device_eval_batch_size  = 64,
    learning_rate               = 2e-5,                 # Gentle learning rate for foundation adaptation
    lr_scheduler_type           = 'cosine',
    warmup_steps                = 10,
    eval_strategy               = 'epoch',
    save_strategy               = 'epoch',
    load_best_model_at_end      = True,
    metric_for_best_model       = 'eval_loss',
    greater_is_better           = False,
    save_total_limit            = 2,
    logging_steps               = 5,
    report_to                   = 'none',
    seed                        = 42,
)

trainer = Trainer(
    model        = fs_model,
    args         = training_args,
    train_dataset= fs_train_ds,
    eval_dataset = fs_val_ds,
    callbacks    = [
        EarlyStoppingCallback(
            early_stopping_patience  = 3,
            early_stopping_threshold = 0.0005,
        )
    ],
)

print(f'Fine-tuning on {len(fs_train_ds)} windows…')
t0 = time.time()
trainer.train()
finetune_time = time.time() - t0
print(f'Fine-tuning completed in {finetune_time:.1f}s  ({finetune_time/60:.1f} min)')
# Out:
# Loading weights:   0%|          | 0/134 [00:00<?, ?it/s]
# Trainable parameters: 805,280
# Fine-tuning on 1197 windows…
#     <div>
#
#       <progress value='190' max='190' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [190/190 00:25, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.118783</td>
#       <td>0.130140</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.102594</td>
#       <td>0.121034</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.101714</td>
#       <td>0.116794</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.092827</td>
#       <td>0.116390</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.089484</td>
#       <td>0.114866</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.086067</td>
#       <td>0.113464</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.080547</td>
#       <td>0.112648</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.076786</td>
#       <td>0.112332</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.090528</td>
#       <td>0.112065</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.082626</td>
#       <td>0.112044</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Fine-tuning completed in 28.0s  (0.5 min)

# %%
# Plot fine-tuning loss
log_history = trainer.state.log_history
train_losses = [e['loss'] for e in log_history if 'loss' in e and 'eval_loss' not in e]
eval_losses  = [e['eval_loss'] for e in log_history if 'eval_loss' in e]

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(train_losses, label='Train loss')
if eval_losses:
    eval_x = np.linspace(0, len(train_losses)-1, len(eval_losses))
    ax.plot(eval_x, eval_losses, label='Val loss', linestyle='--')
ax.set_title('TTM few-shot fine-tuning loss')
ax.set_xlabel('Step')
ax.legend()
plt.tight_layout()
plt.savefig('data/fig_ttm_finetune.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
fs_model.eval()
fs_model = fs_model.to(DEVICE)

# Re-use the same test dataset built for zero-shot
fs_loader = DataLoader(test_dataset_zs, batch_size=64, shuffle=False,
                       collate_fn=collate_skip_timestamps)


t0 = time.time()
preds_fs, trues_fs = [], []

with torch.no_grad():
    for batch in fs_loader:
        past_values = batch['past_values'].to(DEVICE)
        outputs     = fs_model(past_values=past_values)
        preds_fs.append(outputs.prediction_outputs.cpu().numpy())
        trues_fs.append(batch['future_values'].numpy())

inference_time_fs = time.time() - t0

preds_fs = np.concatenate(preds_fs, axis=0)
trues_fs = np.concatenate(trues_fs, axis=0)

y_pred_fs = preds_fs[:, :, 0].ravel() * target_std + target_mean
y_true_fs = trues_fs[:, :, 0].ravel() * target_std + target_mean

print(f'Inference time (few-shot): {inference_time_fs:.2f}s')
print(f'Forecast points: {len(y_pred_fs):,}')
# Out:
# Inference time (few-shot): 0.11s
# Forecast points: 9,744

# %%
metrics_fs = du.compute_metrics(y_true_fs, y_pred_fs, label='TTM few-shot')
metrics_fs['train_s']     = finetune_time
metrics_fs['inference_s'] = inference_time_fs
# Out:
# [TTM few-shot] MAPE=5.479%  RMSE=1661.4 MW  MAE=1183.8 MW

# %% [markdown]
# ## 7 · Plots

# %%
# Build datetime array for test predictions
n_windows  = len(preds_zs)
dates_test = df_for_zs_test['datetime'].values

dates_zs = np.concatenate([
    dates_test[CONTEXT_LEN + i * HORIZON : CONTEXT_LEN + i * HORIZON + HORIZON]
    for i in range(n_windows)
])
dates_zs = pd.to_datetime(dates_zs)

# %%
du.plot_predictions(
    y_true_zs[:168], y_pred_zs[:168],
    title     = 'TTM zero-shot — first week of test set',
    dates     = dates_zs[:168],
    save_path = 'data/fig_ttm_zeroshot_week.png',
)
# Out:
# Figure saved → data/fig_ttm_zeroshot_week.png

# %%
du.plot_predictions(
    y_true_fs[:168], y_pred_fs[:168],
    title     = 'TTM few-shot — first week of test set',
    dates     = dates_zs[:168],
    save_path = 'data/fig_ttm_fewshot_week.png',
)
# Out:
# Figure saved → data/fig_ttm_fewshot_week.png

# %%
# Side-by-side zero-shot vs few-shot (one representative week)
idx = slice(0, 168)
fig, axes = plt.subplots(2, 1, figsize=(14, 8), sharex=True)
for ax, y_pred, label, color in [
    (axes[0], y_pred_zs[idx], 'Zero-shot', '#ff7f0e'),
    (axes[1], y_pred_fs[idx], 'Few-shot',  '#2ca02c'),
]:
    ax.plot(dates_zs[idx], y_true_zs[idx], label='Actual',  color='#1f77b4', linewidth=1.2)
    ax.plot(dates_zs[idx], y_pred,          label=label,   color=color, linewidth=1.2, linestyle='--')
    ax.set_title(f'TTM {label}')
    ax.set_ylabel('Demand (MW)')
    ax.legend()
axes[1].xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))
plt.tight_layout()
plt.savefig('data/fig_ttm_comparison_week.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 8 · Save predictions and metrics

# %%
# Zero-shot
pd.DataFrame({'datetime': dates_zs, 'y_true': y_true_zs, 'y_pred': y_pred_zs}).to_csv(
    'data/predictions_ttm_zeroshot.csv', index=False
)
with open('data/metrics_ttm_zeroshot.json', 'w') as f:
    json.dump(metrics_zs, f, indent=2)

# Few-shot
pd.DataFrame({'datetime': dates_zs, 'y_true': y_true_fs, 'y_pred': y_pred_fs}).to_csv(
    'data/predictions_ttm_fewshot.csv', index=False
)
with open('data/metrics_ttm_fewshot.json', 'w') as f:
    json.dump(metrics_fs, f, indent=2)

print('Saved predictions and metrics for both TTM modes.')
print('\nZero-shot metrics:', metrics_zs)
print('Few-shot  metrics:', metrics_fs)

# Sync outputs to Google Drive (if in Colab)
du.sync_to_drive()
# Out:
# Saved predictions and metrics for both TTM modes.
#
# Zero-shot metrics: {'mape': 6.108983154142127, 'rmse': 1828.7279631903975, 'mae': 1336.079592452576, 'train_s': 0.0, 'inference_s': 1.1112618446350098}
# Few-shot  metrics: {'mape': 5.47941036682944, 'rmse': 1661.3878788476948, 'mae': 1183.841786399966, 'train_s': 28.047091722488403, 'inference_s': 0.11319327354431152}
#   [DriveSync] Uploading data/fig_acf_pacf.png to Drive...
#   [DriveSync] Uploading data/fig_stl_decomposition.png to Drive...
#   [DriveSync] Uploading data/fig_sarimax_week.png to Drive...
#   [DriveSync] Uploading data/metrics_ttm_zeroshot.json to Drive...
#   [DriveSync] Uploading data/fig_ttm_zeroshot_week.png to Drive...
#   [DriveSync] Uploading data/fig_ttm_comparison_week.png to Drive...
#   [DriveSync] Uploading data/features_val.csv to Drive...
#   [DriveSync] Uploading data/predictions_lstm.csv to Drive...
#   [DriveSync] Uploading data/fig_pearson_correlation.png to Drive...
#   [DriveSync] Uploading data/fig_lstm_training.png to Drive...
#   [DriveSync] Uploading data/fig_ttm_finetune.png to Drive...
#   [DriveSync] Uploading data/fig_lstm_residuals.png to Drive...
#   [DriveSync] Uploading data/metrics_sarimax.json to Drive...
#   [DriveSync] Uploading data/predictions_sarimax.csv to Drive...
#   [DriveSync] Uploading data/fig_raw_demand.png to Drive...
#   [DriveSync] Uploading data/fig_lstm_week.png to Drive...
#   [DriveSync] Uploading data/fig_lstm_test.png to Drive...
#   [DriveSync] Uploading data/metrics_lstm.json to Drive...
#   [DriveSync] Uploading data/hourly_features_full.csv to Drive...
#   [DriveSync] Uploading data/fig_sarimax_test.png to Drive...
#   [DriveSync] Uploading data/fig_data_split.png to Drive...
#   [DriveSync] Uploading data/predictions_ttm_zeroshot.csv to Drive...
#   [DriveSync] Uploading data/fig_ttm_fewshot_week.png to Drive...
#   [DriveSync] Uploading data/fig_sarimax_residuals.png to Drive...
#   [DriveSync] Uploading data/metrics_ttm_fewshot.json to Drive...
#   [DriveSync] Uploading data/fig_seasonality.png to Drive...
#   [DriveSync] Uploading data/features_train.csv to Drive...
#   [DriveSync] Uploading data/features_test.csv to Drive...
#   [DriveSync] Uploading data/predictions_ttm_fewshot.csv to Drive...
#   [DriveSync] Uploading data/fig_boxcox.png to Drive...
#   [DriveSync] Uploading cache/esios_chunk_ce0872f58f12cb7b4c73d5f36f4a5580.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_ad082ad2ca00cba8a6d4a4869db29f4e.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_ee59568009c9a40e75b0014a1fc92104.pkl to Drive...
#   [DriveSync] Uploading cache/openmeteo_5a2942590f7449a0b98e9ab046c3ef7f.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_8f0c90d24f2649bc64678e7729690792.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_519aa3f7d5dd978345f9e2afa1cfd787.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_d3d2e60f51fcbc5fba985541581db99d.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_c26d7938cfc50f0d9106260a61c8ccb9.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_ca0a546d4281cf60427efdbca11c4639.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_6153281b49a9e083fc50bfa4e0815ad9.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_a2ecb9461c2c71aa659a51d4a99c655e.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_8b2b684148b02002b5867948213024e7.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_17994abd81f14cdd92ea187c68f691f9.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_763edfe57aebef24a2bb28a246bc340c.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_23eaea2912ff4c00c128c84e32fd29cf.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_e9d2b83992db0d8e5c8e9a82e49b1065.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_257693848ec50cc9d1c36b9c084e02bd.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_97e7857fcb710058642282549e2b625d.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_6466513cc67f7bf838c219626c421c67.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_9844632642bdce5705f0307c1efed2d0.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_37b133d9716e3876cee22473aca69e9e.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_1e0031d40b1c66002db3a298a0fd09b6.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_54f911966bb33d733dc14f2a09e5f881.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_51196a5bc5a2fb0fe22647795c1fb569.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_a34cbcfb1aacc0115498645223ad8d86.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_aa6bf8aa0be0c756d424d29f1ac0bbf5.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_018a4f151f09d31bd254330f63cda7c4.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_2e20f6b00d5664c9ae050b54e164b649.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_8ad5833b4208904baa740ea21ca7b1be.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_ab89c85fcb567c1f27196f33229f805d.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_3286042738b4042669013ee7ec9149f7.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_47f5251e7448a990f344c3ccba87097c.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_96d5a75537393184b6d27ea19004b268.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_5d2c34fa98a21920666f493ef49dad56.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_8d92c2e94cf97b5d2d1fc3bbdd5b3ddb.pkl to Drive...
#   [DriveSync] Uploading cache/openmeteo_8142cc6552233faea0ae6a2154340a30.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_69f9d4b7ba466401fb64c0dca86d7feb.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_b10cfb5790b9933c7a287b0982287b92.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_4da9739fe4aa2556f86a596c0307bf8a.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_e4e092c57e069e923daa27d80adc33dd.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_b85ea7903132d8e1b6805747cb9529d0.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_8ebad3b87a2566b97b2393d74c544e90.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_23224be23d237eb4281701cd9aee7829.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_17d302c92843387ddb79f07effe717a9.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_772df9ca8320adab4276c220cc029972.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_db9626bae8b1b6de9699bd6c0128e686.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_e3655cb0e3ed8854e84c2bb81b2543d5.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_4b79b19bc2253ff965d9cc46dfe3137d.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_07173a25320a00a20cf700479646e579.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_ab254ef7bed6acc37e5841302396ab62.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_a2ad0c6e679aa032602ced1d1369bbd4.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_73ea90391c818c722eab9dd92d482958.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_a77962559435733f496d5438e86dba3c.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_6e5f2c2dbd41f366355aed4c8adbe81b.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_877776a74e30476740bc36153817aac8.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_de8400b261055c6b2bd3cd78d6539802.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_48f9263eb87d9a5a34a79e756dcb2145.pkl to Drive...
#   [DriveSync] Uploading cache/esios_00ecea6a9172671e29ec3d65e5617f3f.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_ca3a199a0d77ffebcd001aa417151c0d.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_db90a6c5b4372da9b83d14e1ec34d807.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_b8546100ea247c2b31998f366c31e827.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_4ad3359681b81a3ac70d42c0a1c95c8b.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_3eec930341dae5d150f85a9b631db468.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_91a38cea51bfe7e40f9e15f2993543ef.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_39816a5e1d04562e01f411db1c28a7f9.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_edfb372e75a879e69c14711682a28f11.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_d31874962515cbfcc53c256c6c955713.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_ba0b69f78cd23a19058c9dd14f218050.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_04233c88a47818dcf34577ad9896d657.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_3b64ff5000ec74d1d1538277a8273c5d.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_067b43ea58fc06ea262ed3ae6e71262d.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_91262a792181b2c4f9f9706684e53a79.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_38629c98a5299dd5877119dcd915d3c5.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_1b56ccf9551c6177ab16572b2b25242f.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_98b0f211d838bbdf4dd71e2c69784881.pkl to Drive...
#   [DriveSync] Uploading cache/esios_77a3abc1fb28157a9ad20ac4653588dc.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_059c27ff0db1037572cf64253fbc7e95.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_2ed56b724e28c8bece31bc57503b48e8.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_648c54b5e1fb9d6aebbbc94ad67ffa78.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_16199e237279463f71501809aafd0102.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_096097e19fc09026c1d8f0d50a937213.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_59f29187ddcbb77bf612dfcb355435e5.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_f5b6baa14b1e4bde23757d8ac4991681.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_2b545e41a47ba530514eac6e4a787fde.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_c4769404bfd7adf6bd55d4dc2c0cda04.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_ec5da5d02da0d51983e75f6576ee5c35.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_28cb2bc6a803bd0c574cf0d8c05e13a6.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_e397bee21e61eb5df0ad3e65228b3693.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_ec646bf1f3169df5bcd05867e20fd737.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_19c8d48bd32903ea72f6d344ce1a0bce.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_b9eb979afae1a3ff85cd03d8bc86c9ec.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_effb268722b7fbcc0743443415c052cc.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_ab6f9fb9b5391eda8bced7e43617aae2.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_a7d832fd9b5e6add152e5e7456f3f298.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_0ba17a15a3c8a15cd531c19f28184c79.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_ed9eee70691b3750f51bbe1e9837c646.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_278fa8a241c8fdd5479daa569a1421e0.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_2f49521107f29cd3efcc3a98da7eb27f.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_a9e86e8a2796358418583e0bcf45d62b.pkl to Drive...
#   [DriveSync] Uploading cache/esios_chunk_77722c1924bf152a186b57ff9e13349d.pkl to Drive...
#   [DriveSync] Uploading saved_models/lstm_best.keras to Drive...
# [DriveSync] Upload to Google Drive complete.
# True

# %% [markdown]
# ## Summary
#
# | Mode | MAPE (%) | RMSE (MW) | MAE (MW) | Fine-tune time |
# |------|----------|-----------|----------|----------------|
# | Zero-shot | … | … | … | 0 s |
# | Few-shot  | … | … | … | … s |
#
# Next step → `fase3_validacion_y_comparativa.ipynb`

# %%
#Terminate runtime
from google.colab import runtime
runtime.unassign()
